OYwrx6ifvOFz5HyBGzKZCytSONcMYioqfcbxbO4ExteUmmknWrvmsUND2r3f2NYxq_IoH5JNMQQDT6PYivKhmttBOIbIn6tWWcob4l-2aeGfRHcyIQn44BxXcp4jvqh4ZGqMlCj6rDp0nNAe8r3swCmcXsIUoyXnsgRLnlGQGYIVU3-iX-Cc_B4sKUQKKmmy_innV0yn3rPiHaGbruPuFB8EU8bqaXM5xU5sSw6T9ipoS5KcJpreFyHzjHalLHTQtbrWwYO3aAYWtDK_ft9Y9bEO_Z2NAaAnmp1bkyVClzN1xfhzBKUh6PB8aUrt5SQ06SmGBdNX1mzSC24kDiUpWzhDuRm2ri7JoQcmMP5XXDAvN-UDiodqBx6dFLjoCG3eLJNBM8TteYfMZdKL_VX9gZ0QggsJtKioXim9cU6-Agkl6PeJZFsRdDtOPt-8lj7hYg5-AU8o3kD_S7fy4OT2nR6LjSRPG8k5ODADAjNEVrNSarI8_hWIgoMPlIo6NB_bLgIXDfT4hjmIMkFLa95aZjmZ4MVj-nWzU8pa6Sa_Ce-PXbzG9TK1eMXM7nTDArWS2CkOn7F-HvWtksiweABwjMenMzdp1nyKdlbUUgwtyZKQ5O7hYOwEPWw1Ichb-wsCf_1Zu3XO8jTJRxSXgHcRfCyK7mRe9ELZdUC-7YHnb1wVU6sxMSZw92lYEEr2qhd9xr-6lft2zFdnOdlxpGP1M8hWADiE1SA3AW3RQWo75a4DXZHCWmxLIAiPzF0e3KaxS9D20M-BKNEmRlXvZv3MQrm9U69oKdT_Ecc-0kvm0D-Sn4G1WiiZw20PDgxy9aJm3ENFgSuMJgpU3sBWq0hfnctCAav_Wwe5bqmYuDny8ldHvz6_uQcs5tbZEUACPqxmp2SR_cl22xHRcH3fYlxzZahz9YeZ4t-MVJMWt1ZxZGgXFO-f_zqtob7x-QRHgriDfYv7bhZ_3YUfE_7rOkJ.xCV8VZ5cF5Q-aWcuFFoItA" # Enter your session token here!

# %%
model = whisper.load_model("base")
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 117MiB/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Transcribe Function

# %%
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)
    print('audio input done')
    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)
    print('audio fitting in model done')
    # detect the spoken language
    _, probs = model.detect_language(mel)
    print('Language detection done')
    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    result_text = result.text
    print('audio to text Done')
    # Pass the generated text to Audio
    chatgpt_api = ChatGPT(secret_token)
    resp = chatgpt_api.send_message(result_text)
    out_result = resp['message']

    return [result_text, out_result]

# %%
# !pip install PyVirtualDisplay
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
result_text = "Hey How are you doing"

chatgpt_api = ChatGPT(secret_token)
resp = chatgpt_api.send_message(result_text)
out_result = resp['message']
print(out_result)
# Out:
# DEBUG:pyChatGPT:Starting virtual display...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pyChatGPT/pyChatGPT.py in __init_browser(self)
#     162
# --> 163                 self.display = Display()
#     164             except ModuleNotFoundError:
#
# /usr/local/lib/python3.8/dist-packages/pyvirtualdisplay/display.py in __init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      53
# ---> 54         self._obj = cls(
#      55             size=size,
#
# /usr/local/lib/python3.8/dist-packages/pyvirtualdisplay/xvfb.py in __init__(self, size, color_depth, bgcolor, use_xauth, fbdir, dpi, retries, extra_args, manage_global_env)
#      43
# ---> 44         AbstractDisplay.__init__(
#      45             self,
#
# ...

# %% [markdown]
# # Gradio Interface

# %%
output_1 = gr.Textbox(label="Speech to Text")
output_2 = gr.Textbox(label="ChatGPT Output")


gr.Interface(
    title = 'OpenAI Whisper and ChatGPT ASR Gradio Web UI', 
    fn=transcribe, 
    inputs=[
        gr.inputs.Audio(source="microphone", type="filepath")
    ],

    outputs=[
        output_1,  output_2
    ],
    live=True).launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
